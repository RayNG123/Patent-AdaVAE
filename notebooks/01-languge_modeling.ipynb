# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/innovae-revision/innovae-adavae')

# !pip install transformers
# !pip install tensorboardX
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 15.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 21.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 35.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 45.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 1.7 MB/s eta 0:00:00
# ...

# %%
cd adavae/src
# Out:
# /content/drive/.shortcut-targets-by-id/1Sc8fDGyiYvHq5OEtFiwe-8tIhrfMocsw/innovae-revision/innovae-adavae/adavae/src

# %%
# !python adaVAE.py \
    --batch-sizes 40 --dataset patent_claim \
    --max_length 400 --pre_enc_iter start \
    --add_attn --beta_0 1 \
    --fb 1 --latent_gen latent_attn \
    --adapter_size 128 --iterations 26272 \
    --weighted_sample \
    --latent_size 512 \
    --encoder_n_layer 8 \
    --decoder_n_layer 12 \
    --adapter_init bert \
    --attn_mode none  \
    --kl_rate 0.50
